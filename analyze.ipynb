# %%
import pandas as pd

# %%
df = pd.read_parquet('E4ZNTW6XOW5DN.2025-04-12-15.b3632fd3.parquet')

# Set max_columns to None to display all columns
pd.options.display.max_columns = None

# %%
# Data inspection
print("df Info:")
df.info()
print("df description:")
df.describe()
df.head()
# Out:
# df Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         2 non-null      object
#  1   time                         2 non-null      object
#  2   x_edge_location              2 non-null      object
#  3   sc_bytes                     2 non-null      object
#  4   c_ip                         2 non-null      object
#  5   cs_method                    2 non-null      object
#  6   cs_Host                      2 non-null      object
#  7   cs_uri_stem                  2 non-null      object
#  8   sc_status                    2 non-null      object
#  9   cs_Referer                   2 non-null      object
#  10  cs_User_Agent                2 non-null      object
#  11  cs_uri_query                 2 non-null      object
#  12  cs_Cookie                    2 non-null      object
#  13  x_edge_result_type           2 non-null      object
#  14  x_edge_request_id            2 non-null      object
#  15  x_host_header                2 non-null      object
#  16  cs_protocol                  2 non-null      object
#  17  cs_bytes                     2 non-null      object
#  18  time_taken                   2 non-null      object
#  19  x_forwarded_for              2 non-null      object
#  20  ssl_protocol                 2 non-null      object
#  21  ssl_cipher                   2 non-null      object
#  22  x_edge_response_result_type  2 non-null      object
#  23  cs_protocol_version          2 non-null      object
#  24  fle_status                   2 non-null      object
#  25  fle_encrypted_fields         2 non-null      object
#  26  c_port                       2 non-null      object
#  27  time_to_first_byte           2 non-null      object
#  28  x_edge_detailed_result_type  2 non-null      object
#  29  sc_content_type              2 non-null      object
#  30  sc_content_len               2 non-null      object
#  31  sc_range_start               2 non-null      object
#  32  sc_range_end                 2 non-null      object
# dtypes: object(33)
# memory usage: 656.0+ bytes
# df description:
#          date      time x_edge_location sc_bytes          c_ip cs_method  \
# 0  2025-04-12  15:07:14        IAD55-P6      570  13.82.195.38       GET
# 1  2025-04-12  15:07:14        IAD55-P6     1211  13.82.195.38       GET
#
#                         cs_Host cs_uri_stem sc_status cs_Referer  \
# 0  d8bnainxtot1t.cloudfront.net           /       301          -
# 1  d8bnainxtot1t.cloudfront.net           /       200          -
#
#                                        cs_User_Agent cs_uri_query cs_Cookie  \
# 0  Mozilla/5.0%20(Windows%20NT%206.1;%20WOW64)%20...            -         -
# 1  Mozilla/5.0%20(Windows%20NT%206.1;%20WOW64)%20...            -         -
#
#   x_edge_result_type                                  x_edge_request_id  \
# 0           Redirect  2tTE36o5fu_cIAyu2OhlgqkZX2IOcOafPIAngz0oP9paGf...
# 1               Miss  Ej4JLR8qTOLYgqMDbuCGcD8S96lLDg84Dm1Rhc1_j-1os6...
#
#                x_host_header cs_protocol cs_bytes time_taken x_forwarded_for  \
# 0  archivesnationales-ht.com        http      300      0.001               -
# 1  archivesnationales-ht.com       https      300      0.053               -
#
#   ssl_protocol                   ssl_cipher x_edge_response_result_type  \
# 0            -                            -                    Redirect
# 1      TLSv1.2  ECDHE-RSA-AES128-GCM-SHA256                        Miss
#
#   cs_protocol_version fle_status fle_encrypted_fields c_port  \
# 0            HTTP/1.1          -                    -  57145
# 1            HTTP/1.1          -                    -  57147
#
#   time_to_first_byte x_edge_detailed_result_type sc_content_type  \
# 0              0.001                    Redirect       text/html
# 1              0.053                        Miss       text/html
#
#   sc_content_len sc_range_start sc_range_end
# 0            167              -            -
# 1            727              -            -

# %%
df.head()

# %%
aws_location_df = pd.read_parquet('aws-edge-locations.parquet')
aws_location_df.head(10)

# %%
aws_location_df[aws_location_df['code'] == 'HEL']
